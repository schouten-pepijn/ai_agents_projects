# %%
from docling.document_converter import DocumentConverter
import torch



# if torch.cuda.is_available():
#     torch.set_default_tensor_type(torch.cuda.FloatTensor)
#     torch.cuda.empty_cache()
#     device = torch.device("cuda")

source = "C:\\Users\\71861\\Own\\Projects\\AI\\AI_showcase_projects\\invoice_extraction\\data\\invoice_1.jpg"  # file path or URL

converter = DocumentConverter()
doc = converter.convert(source).document

print(doc.export_to_markdown())  # output: "### Docling Technical Report[...]"
# Out:
# 2025-09-29 08:14:55,883 - INFO - detected formats: [<InputFormat.IMAGE: 'image'>]
# 2025-09-29 08:14:55,949 - INFO - Going to convert document batch...
# 2025-09-29 08:14:55,949 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-09-29 08:14:56,082 - INFO - Loading plugin 'docling_defaults'
# 2025-09-29 08:14:56,084 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-09-29 08:14:56,084 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-09-29 08:14:56,118 - INFO - Loading plugin 'docling_defaults'
# 2025-09-29 08:14:56,121 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-09-29 08:14:56,121 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-09-29 08:14:56,212 - INFO - Accelerator device: 'cuda:0'
# 2025-09-29 08:14:57,488 - INFO - Accelerator device: 'cuda:0'
# 2025-09-29 08:14:58,282 - INFO - Accelerator device: 'cuda:0'
# 2025-09-29 08:14:58,596 - INFO - Processing document invoice_1.jpg
# 2025-09-29 08:15:01,880 - INFO - Finished converting document invoice_1.jpg in 6.00 sec.
# Ms Pia Rutschmann Marktgasse 28 9400 Rorschach
#
# Dear Ms. Rutschmann,
#
# We are billing you as follows for completion of the assigned activities:
#
# ## Bill no. 3139
#
# | Item   | Description          | Amount   | Individual price   | Total         |
# |--------|----------------------|----------|--------------------|---------------|
# | 1      | Garden work          | 28 Std . | CHF 120.00         | CHF 3 360.00  |
# | 2      | Disposal of cuttings |          | CHF 307.35         | CHF 307.35    |
# |        |                      |          | sum                | CHF 3* 667.35 |
# |        |                      |          | VATrate            |               |
# |        |                      |          | VATamount          | CHF 282.40    |
# |        |                      |          | Bill amount        | CHF 3 949.75  |
#
# Thank you for the assignment. Please pay the bill amount within 30 days.
#
# Yours sincerely;
#
# Robert Schneider
#
# ## Receipt
#
# Account / Payable to
#
# Robert Schneider AG Rue du Lac 1268 2501 Biel
#
# Payablø by Pia Rutschmann Marklgasse 28
#
# 9400 Rorschach
#
# Currency
#
# Amount
#
# CHF
#
# 3 949.75
#
# Acceptance point
#
# ## Fictitious example for illustration purposes
#
# Robert Schneider AG Rue du Lac 1268 2501 Biel
#
# Telefon: 059/987 6540
#
# Mobil: 079/987 65 43
#
# E-Mail: robert @rschneider ch
#
# Internet: www.rschneider .ch
#
# Date: 01.07.2020
#
# Payment part
#
# <!-- image -->
#
# Currency
#
# Amount
#
# CHF
#
# 3 949.75
#
# Account / Payable to CH58 0079 1123 0008 8901 2 Robert Schneider AG Rue du Lac 1268 2501 Biel
#
# Additional information Bill No. 3139 for garden work and disposal of cuttings
#
# Payable by Pia Rutschmann Marktgasse 28
#
# 9400 Rorschach
